# %%
from pynq import Overlay
ol = Overlay('/usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/overlays/prueba_LB_Int/DIS.bit')

# %%
Mux=ol.Mux_and_Data.Multiplexor_0
Mux.write(0x0,1) # Se selecciona la secuencia de entrada

# %%
Rx=ol.Rx_and_ILAs.Rx_monitorizado_0
Rx.write(0x0,2) # Se defina el escalado del Umbral de detección
